# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys1 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-2ed44399b518> in <module>
#       7
#       8 # Import API key
# ----> 9 from api_keys1 import api_key
#      10
#      11 # Incorporated citipy to determine city based on latitude and longitude
#
# ModuleNotFoundError: No module named 'api_keys1'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
#api_key=api_keys1.api_key

# Starting URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start counter 
record = 1

print(f"Connecting to OpenWeatherMap API")
print(f"===================================")

# Loop through all cities in the list
for city in cities:  
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Add to counter
        record= record + 1
        
        # API rate limit
        time.sleep(1.01)
        
    # Skip if no match found
    except:
        print("No match found. Skipping to next city.")
    continue
# Out:
# Connecting to OpenWeatherMap API
# ===================================
# Processing Record 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ushuaia
# Processing Record 2 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=busselton
# Processing Record 3 | Sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sibu
# Processing Record 4 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=itoman
# Processing Record 5 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=te anau
# Processing Record 6 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hamilton
# Processing Record 7 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=albany
# Processing Record 8 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ulladulla
# No match found. Skipping to next city.
# Processing Record 9 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=qaqortoq
# No match found. Skipping to next city.
# Processing Record 10 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=upernavik
# Processing Record 11 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kapaa
# Processing Record 12 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dwarka
# No match found. Skipping to next city.
# Processing Record 13 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dikson
# Processing Record 14 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=rikitea
# Processing Record 15 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=east london
# No match found. Skipping to next city.
# No match found. Skipping to next city.
# Processing Record 16 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mataura
# Processing Record 17 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=longyearbyen
# Processing Record 18 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=punta arenas
# Processing Record 19 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dingle
# Processing Record 20 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=qaanaaq
# Processing Record 21 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=thinadhoo
# Processing Record 22 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=beloha
# No match found. Skipping to next city.
# Processing Record 23 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sambava
# Processing Record 24 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=zyryanka
# No match found. Skipping to next city.
# Processing Record 25 | Soure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=soure
# Processing Record 26 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bethel
# No match found. Skipping to next city.
# Processing Record 27 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=saskylakh
# Processing Record 28 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vaini
# Processing Record 29 | Mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mantua
# Processing Record 30 | Amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=amapa
# Processing Record 31 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cape town
# Processing Record 32 | Nayoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nayoro
# Processing Record 33 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=comodoro rivadavia
# Processing Record 34 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=leningradskiy
# Processing Record 35 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hilo
# No match found. Skipping to next city.
# Processing Record 36 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hermanus
# Processing Record 37 | Sarankhola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sarankhola
# Processing Record 38 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=carnarvon
# Processing Record 39 | Kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kendari
# Processing Record 40 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=butaritari
# Processing Record 41 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nelson bay
# Processing Record 42 | Lesnyye Polyany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lesnyye polyany
# Processing Record 43 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kodiak
# Processing Record 44 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=coihaique
# Processing Record 45 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yellowknife
# Processing Record 46 | Kerrville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kerrville
# Processing Record 47 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=goderich
# Processing Record 48 | Wairoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=wairoa
# Processing Record 49 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=port alfred
# Processing Record 50 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hasaki
# Processing Record 51 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=saint-pierre
# Processing Record 52 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=port macquarie
# Processing Record 53 | Creetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=creetown
# Processing Record 54 | Espera Feliz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=espera feliz
# Processing Record 55 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sitka
# Processing Record 56 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=puerto ayora
# Processing Record 57 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=muros
# Processing Record 58 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=coquimbo
# Processing Record 59 | Tefe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tefe
# Processing Record 60 | Burla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=burla
# Processing Record 61 | Kursumlija
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kursumlija
# Processing Record 62 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cidreira
# Processing Record 63 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=port elizabeth
# Processing Record 64 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kaitangata
# Processing Record 65 | Normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=normandin
# Processing Record 66 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=atuona
# Processing Record 67 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=saldanha
# Processing Record 68 | Businga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=businga
# Processing Record 69 | Kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kropotkin
# Processing Record 70 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hobyo
# Processing Record 71 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sao filipe
# Processing Record 72 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=itarema
# Processing Record 73 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hobart
# Processing Record 74 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=naze
# Processing Record 75 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=rocha
# Processing Record 76 | Dinar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dinar
# Processing Record 77 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=victoria
# Processing Record 78 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=avarua
# Processing Record 79 | Cicero Dantas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cicero dantas
# Processing Record 80 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cabo san lucas
# Processing Record 81 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bluff
# Processing Record 82 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=katsuura
# Processing Record 83 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tuktoyaktuk
# Processing Record 84 | Pouembout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pouembout
# Processing Record 85 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=namibe
# Processing Record 86 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mar del plata
# Processing Record 87 | La Asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=la asuncion
# Processing Record 88 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=petropavlovsk-kamchatskiy
# Processing Record 89 | Nisia Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nisia floresta
# Processing Record 90 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=provideniya
# Processing Record 91 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ilulissat
# Processing Record 92 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pevek
# Processing Record 93 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cap malheureux
# Processing Record 94 | Okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=okato
# Processing Record 95 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tiksi
# Processing Record 96 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=severo-kurilsk
# Processing Record 97 | Mataram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mataram
# Processing Record 98 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ust-kuyga
# Processing Record 99 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=castro
# Processing Record 100 | Burias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=burias
# Processing Record 101 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=khatanga
# Processing Record 102 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=aksu
# Processing Record 103 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=torbay
# No match found. Skipping to next city.
# Processing Record 104 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=chuy
# Processing Record 105 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=taoudenni
# No match found. Skipping to next city.
# Processing Record 106 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=saint-philippe
# Processing Record 107 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san quintin
# No match found. Skipping to next city.
# Processing Record 108 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=deputatskiy
# Processing Record 109 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bambanglipuro
# Processing Record 110 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sisimiut
# Processing Record 111 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=burnie
# Processing Record 112 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lompoc
# Processing Record 113 | Xinmin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=xinmin
# Processing Record 114 | Assiniboia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=assiniboia
# Processing Record 115 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=new norfolk
# Processing Record 116 | Indianola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=indianola
# No match found. Skipping to next city.
# Processing Record 117 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cairns
# Processing Record 118 | Madimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=madimba
# Processing Record 119 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=iqaluit
# No match found. Skipping to next city.
# Processing Record 120 | Norilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=norilsk
# Processing Record 121 | Grand Island
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=grand island
# Processing Record 122 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san cristobal
# Processing Record 123 | Yakima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yakima
# Processing Record 124 | Abu Samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=abu samrah
# Processing Record 125 | Barra do Bugres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=barra do bugres
# Processing Record 126 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lavrentiya
# Processing Record 127 | Besancon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=besancon
# Processing Record 128 | Bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bulgan
# Processing Record 129 | Sayyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sayyan
# No match found. Skipping to next city.
# Processing Record 130 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=aklavik
# Processing Record 131 | Logan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=logan
# Processing Record 132 | Orlovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=orlovskiy
# Processing Record 133 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hokitika
# Processing Record 134 | Angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=angoche
# Processing Record 135 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vardo
# Processing Record 136 | Slave Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=slave lake
# Processing Record 137 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san vicente
# Processing Record 138 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=soyo
# Processing Record 139 | Lac du Bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lac du bonnet
# Processing Record 140 | Los Negros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=los negros
# No match found. Skipping to next city.
# Processing Record 141 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sao joao da barra
# No match found. Skipping to next city.
# Processing Record 142 | Namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=namie
# Processing Record 143 | Pachino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pachino
# Processing Record 144 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sept-iles
# Processing Record 145 | Havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=havoysund
# Processing Record 146 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=codrington
# Processing Record 147 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vestmanna
# Processing Record 148 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mount isa
# Processing Record 149 | Laibin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=laibin
# Processing Record 150 | Lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lucea
# Processing Record 151 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mezen
# Processing Record 152 | Gafanha da Encarnacao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=gafanha da encarnacao
# Processing Record 153 | Varangaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=varangaon
# Processing Record 154 | La Paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=la paz
# Processing Record 155 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=chokurdakh
# Processing Record 156 | Santa Isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=santa isabel
# Processing Record 157 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yulara
# No match found. Skipping to next city.
# Processing Record 158 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bonavista
# Processing Record 159 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tasiilaq
# Processing Record 160 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=solnechnyy
# No match found. Skipping to next city.
# Processing Record 161 | Old Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=old town
# Processing Record 162 | Kudat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kudat
# Processing Record 163 | Tugulym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tugulym
# Processing Record 164 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mehamn
# No match found. Skipping to next city.
# Processing Record 165 | Ningyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ningyang
# Processing Record 166 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mount gambier
# Processing Record 167 | Sa Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sa kaeo
# Processing Record 168 | Forssa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=forssa
# Processing Record 169 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bambous virieux
# Processing Record 170 | Mongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mongo
# Processing Record 171 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=grand gaube
# Processing Record 172 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lebu
# Processing Record 173 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bredasdorp
# Processing Record 174 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=shingu
# Processing Record 175 | Pauini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pauini
# Processing Record 176 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=manokwari
# Processing Record 177 | Dovhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dovhe
# No match found. Skipping to next city.
# Processing Record 178 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nouakchott
# Processing Record 179 | Jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=jasper
# Processing Record 180 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=poum
# Processing Record 181 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vila franca do campo
# Processing Record 182 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vostok
# Processing Record 183 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=jamestown
# Processing Record 184 | Kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kuytun
# Processing Record 185 | Teupasenti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=teupasenti
# Processing Record 186 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=christchurch
# Processing Record 187 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=barrow
# Processing Record 188 | Liku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=liku
# Processing Record 189 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ponta do sol
# Processing Record 190 | Meybod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=meybod
# Processing Record 191 | Belokurikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=belokurikha
# No match found. Skipping to next city.
# Processing Record 192 | Tuapse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tuapse
# Processing Record 193 | Yuncheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yuncheng
# Processing Record 194 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kavieng
# Processing Record 195 | Hauterive
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hauterive
# Processing Record 196 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ugoofaaru
# Processing Record 197 | Bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bontang
# Processing Record 198 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=atar
# Processing Record 199 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=souillac
# Processing Record 200 | Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=doha
# Processing Record 201 | Uppsala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=uppsala
# Processing Record 202 | Jishou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=jishou
# Processing Record 203 | Tvoroyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tvoroyri
# Processing Record 204 | Nizhniy Kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nizhniy kuranakh
# Processing Record 205 | Monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=monrovia
# Processing Record 206 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=flinders
# Processing Record 207 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=port augusta
# Processing Record 208 | Columbus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=columbus
# Processing Record 209 | Kaseda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kaseda
# Processing Record 210 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=talnakh
# Processing Record 211 | Azovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=azovo
# Processing Record 212 | Ust-Ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ust-ishim
# Processing Record 213 | Kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kamina
# Processing Record 214 | Richmond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=richmond
# Processing Record 215 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ribeira grande
# Processing Record 216 | Villa Bruzual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=villa bruzual
# No match found. Skipping to next city.
# Processing Record 217 | Nambale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nambale
# No match found. Skipping to next city.
# Processing Record 218 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=champerico
# Processing Record 219 | Pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pangkalanbuun
# Processing Record 220 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=los llanos de aridane
# Processing Record 221 | Pervomayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pervomayskiy
# Processing Record 222 | New Plymouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=new plymouth
# No match found. Skipping to next city.
# Processing Record 223 | Bokovskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bokovskaya
# Processing Record 224 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sungairaya
# No match found. Skipping to next city.
# Processing Record 225 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=georgetown
# Processing Record 226 | Yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yarada
# Processing Record 227 | Butte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=butte
# Processing Record 228 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nome
# Processing Record 229 | Tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tahe
# Processing Record 230 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=skibbereen
# Processing Record 231 | Dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dalvik
# Processing Record 232 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kutum
# No match found. Skipping to next city.
# Processing Record 233 | Lamu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lamu
# Processing Record 234 | Dolgorukovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dolgorukovo
# Processing Record 235 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nuuk
# Processing Record 236 | Ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ampanihy
# Processing Record 237 | Hosbach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hosbach
# Processing Record 238 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=flin flon
# Processing Record 239 | Astaneh-ye Ashrafiyeh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=astaneh-ye ashrafiyeh
# Processing Record 240 | Puno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=puno
# Processing Record 241 | Sebastian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sebastian
# Processing Record 242 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=arman
# Processing Record 243 | Savonlinna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=savonlinna
# Processing Record 244 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=komsomolskiy
# Processing Record 245 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bilma
# Processing Record 246 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=waipawa
# Processing Record 247 | Panama City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=panama city
# Processing Record 248 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=thompson
# Processing Record 249 | Wahlstedt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=wahlstedt
# No match found. Skipping to next city.
# Processing Record 250 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mahebourg
# Processing Record 251 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kruisfontein
# Processing Record 252 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=belmonte
# Processing Record 253 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nhulunbuy
# Processing Record 254 | Emirdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=emirdag
# Processing Record 255 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=biak
# Processing Record 256 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sobolevo
# No match found. Skipping to next city.
# Processing Record 257 | Talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=talara
# Processing Record 258 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tura
# Processing Record 259 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=srednekolymsk
# Processing Record 260 | Wynyard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=wynyard
# Processing Record 261 | Aberdeen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=aberdeen
# Processing Record 262 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=jacareacanga
# Processing Record 263 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bathsheba
# Processing Record 264 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=luderitz
# Processing Record 265 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=arraial do cabo
# Processing Record 266 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yar-sale
# Processing Record 267 | Stawell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=stawell
# Processing Record 268 | Shihezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=shihezi
# No match found. Skipping to next city.
# Processing Record 269 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nabire
# Processing Record 270 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=chapais
# Processing Record 271 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=palmer
# Processing Record 272 | Arroio Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=arroio grande
# Processing Record 273 | Recco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=recco
# Processing Record 274 | At-Bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=at-bashi
# Processing Record 275 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vanimo
# Processing Record 276 | Duku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=duku
# Processing Record 277 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hovd
# Processing Record 278 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=maniitsoq
# Processing Record 279 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=padang
# No match found. Skipping to next city.
# Processing Record 280 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=okha
# Processing Record 281 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=koumac
# No match found. Skipping to next city.
# Processing Record 282 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=homer
# Processing Record 283 | Verkhniy baskunchak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=verkhniy baskunchak
# Processing Record 284 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hithadhoo
# Processing Record 285 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=norman wells
# Processing Record 286 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nago
# Processing Record 287 | Darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=darhan
# Processing Record 288 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nantucket
# Processing Record 289 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=pangody
# Processing Record 290 | Gopalpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=gopalpur
# Processing Record 291 | Visnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=visnes
# Processing Record 292 | Gallup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=gallup
# Processing Record 293 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=atambua
# Processing Record 294 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=riyadh
# Processing Record 295 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bay roberts
# Processing Record 296 | Makinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=makinsk
# Processing Record 297 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=matara
# No match found. Skipping to next city.
# Processing Record 298 | Meadow Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=meadow lake
# Processing Record 299 | Ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ushtobe
# Processing Record 300 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cherskiy
# Processing Record 301 | Bang Saphan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bang saphan
# Processing Record 302 | Det Udom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=det udom
# Processing Record 303 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=rio gallegos
# Processing Record 304 | Bay City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bay city
# Processing Record 305 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=anadyr
# Processing Record 306 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bubaque
# No match found. Skipping to next city.
# Processing Record 307 | Petropavlovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=petropavlovka
# Processing Record 308 | Petatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=petatlan
# Processing Record 309 | Antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=antsohihy
# Processing Record 310 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=clyde river
# No match found. Skipping to next city.
# Processing Record 311 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=avera
# Processing Record 312 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=athabasca
# Processing Record 313 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mayo
# Processing Record 314 | Yamada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yamada
# Processing Record 315 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=egvekinot
# No match found. Skipping to next city.
# Processing Record 316 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=portland
# No match found. Skipping to next city.
# No match found. Skipping to next city.
# No match found. Skipping to next city.
# Processing Record 317 | Marshall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=marshall
# Processing Record 318 | Koroni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=koroni
# Processing Record 319 | Hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hirado
# Processing Record 320 | Chambersburg
# ...
# Processing Record 440 | Impfondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=impfondo
# Processing Record 441 | Muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=muisne
# Processing Record 442 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mackay
# Processing Record 443 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=husavik
# Processing Record 444 | San Juan Bautista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san juan bautista
# Processing Record 445 | Dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dickinson
# Processing Record 446 | Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=porto walter
# Processing Record 447 | Chimoio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=chimoio
# Processing Record 448 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ponta delgada
# No match found. Skipping to next city.
# No match found. Skipping to next city.
# Processing Record 449 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=seoul
# Processing Record 450 | Mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mazagao
# Processing Record 451 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tiznit
# Processing Record 452 | Braniewo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=braniewo
# Processing Record 453 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=batemans bay
# Processing Record 454 | Shirokiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=shirokiy
# Processing Record 455 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=martapura
# Processing Record 456 | Asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=asosa
# Processing Record 457 | Vyazemskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vyazemskiy
# No match found. Skipping to next city.
# Processing Record 458 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=prince rupert
# Processing Record 459 | Yerofey Pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yerofey pavlovich
# Processing Record 460 | Tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tutoia
# Processing Record 461 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=la ronge
# Processing Record 462 | Horodyshche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=horodyshche
# Processing Record 463 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=faanui
# Processing Record 464 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=roma
# No match found. Skipping to next city.
# Processing Record 465 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=coahuayana
# Processing Record 466 | Bouca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bouca
# Processing Record 467 | Kemang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kemang
# Processing Record 468 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=faya
# Processing Record 469 | Xiongzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=xiongzhou
# Processing Record 470 | Horsham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=horsham
# Processing Record 471 | Poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=poronaysk
# Processing Record 472 | San Joaquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san joaquin
# No match found. Skipping to next city.
# Processing Record 473 | Redcliffe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=redcliffe
# Processing Record 474 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kahului
# Processing Record 475 | Ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ucluelet
# Processing Record 476 | Darnah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=darnah
# Processing Record 477 | Ilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ilo
# No match found. Skipping to next city.
# Processing Record 478 | Luxeuil-les-Bains
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=luxeuil-les-bains
# Processing Record 479 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=maragogi
# Processing Record 480 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=margate
# Processing Record 481 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bandarbeyla
# Processing Record 482 | San Rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san rafael
# Processing Record 483 | Bata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=bata
# Processing Record 484 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=quatre cocos
# Processing Record 485 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=banda aceh
# Processing Record 486 | Khvastovichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=khvastovichi
# Processing Record 487 | Novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=novikovo
# No match found. Skipping to next city.
# Processing Record 488 | Mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mnogovershinnyy
# Processing Record 489 | Ruthin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ruthin
# Processing Record 490 | Batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=batagay
# Processing Record 491 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sur
# No match found. Skipping to next city.
# Processing Record 492 | Chulym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=chulym
# Processing Record 493 | Caraballeda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=caraballeda
# Processing Record 494 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=lorengau
# Processing Record 495 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=half moon bay
# Processing Record 496 | Tongzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=tongzi
# Processing Record 497 | Protvino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=protvino
# Processing Record 498 | Daoukro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=daoukro
# Processing Record 499 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=san policarpo
# Processing Record 500 | Nola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nola
# Processing Record 501 | Puerto Madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=puerto madryn
# Processing Record 502 | Jinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=jinan
# Processing Record 503 | Barkhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=barkhan
# No match found. Skipping to next city.
# Processing Record 504 | Abrau-Dyurso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=abrau-dyurso
# Processing Record 505 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kieta
# Processing Record 506 | Segou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=segou
# Processing Record 507 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kaeo
# Processing Record 508 | Nehe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=nehe
# Processing Record 509 | Waitati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=waitati
# Processing Record 510 | Camacupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=camacupa
# Processing Record 511 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kupang
# Processing Record 512 | Cordoba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=cordoba
# Processing Record 513 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=buchanan
# Processing Record 514 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=kimbe
# Processing Record 515 | Dodge City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dodge city
# Processing Record 516 | Arecibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=arecibo
# Processing Record 517 | Yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=yaan
# Processing Record 518 | Shaunavon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=shaunavon
# Processing Record 519 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=teya
# Processing Record 520 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=buin
# Processing Record 521 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=alofi
# Processing Record 522 | Adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=adre
# Processing Record 523 | Maltahohe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=maltahohe
# Processing Record 524 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=calvinia
# Processing Record 525 | Honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=honiara
# Processing Record 526 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=brae
# Processing Record 527 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=ruteng
# Processing Record 528 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=port hedland
# Processing Record 529 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=port blair
# Processing Record 530 | Mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=mildura
# Processing Record 531 | Sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=sangar
# Processing Record 532 | Dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=dolores
# Processing Record 533 | Simpang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=simpang
# Processing Record 534 | Aras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=aras
# Processing Record 535 | Creston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=creston
# No match found. Skipping to next city.
# Processing Record 536 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=hirara
# Processing Record 537 | Diapaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=diapaga
# Processing Record 538 | Don Benito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=don benito
# Processing Record 539 | Vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=vytegra
# Processing Record 540 | Liuzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=liuzhou
# Processing Record 541 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=zhigansk
# Processing Record 542 | Guantanamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=guantanamo
# Processing Record 543 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=guerrero negro
# Processing Record 544 | Demikhovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=demikhovo
# Processing Record 545 | Venado Tuerto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=venado tuerto
# Processing Record 546 | Careiro da Varzea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d4203d120bb7b7ee1c2ae1a3102a6bd&q=careiro da varzea

# %%
weatherpy_dictionary = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create df 
weather_data = pd.DataFrame(weatherpy_dictionary)

# Display count
weather_data.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Save data frame to CSV
weather_data.to_csv('weather_data.csv')

# Display data frame head 
weather_data.head()
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("MaxTemp_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Humidity_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Cloudiness_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("WindSpeed_v_Latitude.png")
plt.show()
